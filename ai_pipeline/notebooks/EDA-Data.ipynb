# %%
import pandas as pd
import numpy as np
import matplotlib as mlt
import csv

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
df_recipes = pd.read_csv('C:/Users/wellb/Downloads/datasets/daily_food_nutrition_dataset.csv')

# %%
df_recipes.columns
# Out:
# Index(['Date', 'User_ID', 'Food_Item', 'Category', 'Calories (kcal)',
#        'Protein (g)', 'Carbohydrates (g)', 'Fat (g)', 'Fiber (g)',
#        'Sugars (g)', 'Sodium (mg)', 'Cholesterol (mg)', 'Meal_Type',
#        'Water_Intake (ml)'],
#       dtype='object')

# %%
df_recipes.head(10)
# Out:
#          Date  User_ID       Food_Item    Category  Calories (kcal)  \
# 0  2024-09-11      496            Eggs        Meat              173
# 1  2024-12-17      201           Apple      Fruits               66
# 2  2024-06-09      776  Chicken Breast        Meat              226
# 3  2024-08-27      112          Banana      Fruits              116
# 4  2024-07-28      622          Banana      Fruits              500
# 5  2024-01-19      620            Oats      Grains              387
# 6  2024-07-27      714          Carrot  Vegetables              138
# 7  2024-10-21      992         Cookies      Snacks               69
# 8  2024-07-23      535           Apple      Fruits              568
# 9  2024-09-08      594          Quinoa      Grains              204
#
#    Protein (g)  Carbohydrates (g)  Fat (g)  Fiber (g)  Sugars (g)  \
# 0         42.4               83.7      1.5        1.5        12.7
# 1         39.2               13.8      3.2        2.6        12.2
# ...

# %%
print(df_recipes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  object
#  1   User_ID            10000 non-null  int64
#  2   Food_Item          10000 non-null  object
#  3   Category           10000 non-null  object
#  4   Calories (kcal)    10000 non-null  int64
#  5   Protein (g)        10000 non-null  float64
#  6   Carbohydrates (g)  10000 non-null  float64
#  7   Fat (g)            10000 non-null  float64
#  8   Fiber (g)          10000 non-null  float64
#  9   Sugars (g)         10000 non-null  float64
#  10  Sodium (mg)        10000 non-null  int64
#  11  Cholesterol (mg)   10000 non-null  int64
#  12  Meal_Type          10000 non-null  object
#  13  Water_Intake (ml)  10000 non-null  int64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.1+ MB
# None

# %%
df_category = df_recipes.groupby('Category').sum().reset_index

# %%
top_nutrition_density_foods = df_category
plt.figure(figsize=(12, 8))
sns.barplot(x='Nutrition Density', y='food', data=top_nutrition_density_foods, palette='viridis')
plt.title('Top 10 Food Items by Nutrition Density')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 top_nutrition_density_foods = df_category
#       2 plt.figure(figsize=(12, 8))
# ----> 3 sns.barplot(x='Nutrition Density', y='food', data=top_nutrition_density_foods, palette='viridis')
#       4 plt.title('Top 10 Food Items by Nutrition Density')
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
# ...

# %%
df_vegan = pd.read_csv('C:/Users/user/Downloads/Datasets-D/vegan.csv')

# %%
print(df_vegan.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1522 entries, 0 to 1521
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Diet_type        1522 non-null   object
#  1   Recipe_name      1522 non-null   object
#  2   Cuisine_type     1522 non-null   object
#  3   Protein(g)       1522 non-null   float64
#  4   Carbs(g)         1522 non-null   float64
#  5   Fat(g)           1522 non-null   float64
#  6   Extraction_day   1522 non-null   object
#  7   Extraction_time  1522 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 95.3+ KB
# None

# %%
df_vegan.head(10)
# Out:
#   Diet_type                                    Recipe_name Cuisine_type  \
# 0     vegan                            Spiked Vegan Eggnog     american
# 1     vegan                  Vegan Cucumber Tea Sandwiches     american
# 2     vegan                     Vegan Broccoli Soup Recipe     american
# 3     vegan              Baked Vegan Mac and Cheese Recipe     american
# 4     vegan                                   Vegan Nachos     american
# 5     vegan              The Best Vegan Breakfast Sandwich     american
# 6     vegan  {Vegan} Peanut Butter & Honey Muffins recipes     american
# 7     vegan                            Vegan Pots de Crème     american
# 8     vegan                                   Vegan tiffin     american
# 9     vegan                         Vegan Stovetop Lasagna     american
#
#    Protein(g)  Carbs(g)  Fat(g) Extraction_day Extraction_time
# 0       46.36     84.52   42.61     2022-10-16        20:02:29
# ...

# %%
df_meal_plans = pd.read_csv('C:/Users/user/Downloads/Datasets-D/healthy_meal_plans.csv')

# %%
print(df_meal_plans.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   meal_name        500 non-null    object
#  1   num_ingredients  500 non-null    float64
#  2   calories         500 non-null    float64
#  3   prep_time        500 non-null    float64
#  4   protein          500 non-null    float64
#  5   fat              500 non-null    float64
#  6   carbs            500 non-null    float64
#  7   vegan            500 non-null    int64
#  8   vegetarian       500 non-null    int64
#  9   keto             500 non-null    int64
#  10  paleo            500 non-null    int64
#  11  gluten_free      500 non-null    int64
#  12  mediterranean    500 non-null    int64
#  13  is_healthy       500 non-null    int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 54.8+ KB
# None

# %%
df_meal_plans.head(10)
# Out:
#                meal_name  num_ingredients  calories  prep_time   protein  \
# 0      Gluten-Free Pasta         0.272727  0.490909       0.84  0.783679
# 1         Grilled Salmon         0.909091  0.158182       0.70  0.143588
# 2            Lentil Soup         0.454545  0.700000       0.40  0.620637
# 3          Chickpea Stew         0.909091  0.105455       0.82  0.046893
# 4   Turkey Lettuce Wraps         0.181818  0.441818       0.04  0.864340
# 5  Cauliflower Rice Bowl         0.272727  0.572727       0.26  0.812533
# 6  Almond Flour Pancakes         1.000000  0.665455       0.12  0.613114
# 7          Chickpea Stew         0.272727  0.703636       0.02  0.427325
# 8  Cauliflower Rice Bowl         0.818182  0.292727       0.18  0.899406
# 9            Vegan Curry         0.545455  0.456364       0.78  0.848855
#
#         fat     carbs  vegan  vegetarian  keto  paleo  gluten_free  \
# 0  0.597907  0.444572      0           0     0      0            1
# ...

# %%
# Import transfore
# pip install transformers

# %%
import transformers
# import Pytorch
import tensorflow as tf 
import pandas as pd
import json
import pandas as pd
import numpy as np
import matplotlib as mlt
import csv

# %%
# from transformers import AutoTokenizer, AutoModelForCausaLLM
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
df_recipes_NGL = pd.read_csv('C:/Users/user/Downloads/Datasets-D/RecipeNLG_dataset.csv')
df_recipes_NGL.head(5)
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# ...

# %%
recipe = df_recipes_NGL['ingredients'][0]
print(type(recipe)
# Out:
# <class 'str'>

# %%
# food dataset
df_food = pd.read_csv('C:/Users/user/Downloads/Datasets-D/daily_food_nutrition_dataset.csv')
df_food.head(5)
# Out:
#          Date  User_ID       Food_Item Category  Calories (kcal)  Protein (g)  \
# 0  2024-09-11      496            Eggs     Meat              173         42.4
# 1  2024-12-17      201           Apple   Fruits               66         39.2
# 2  2024-06-09      776  Chicken Breast     Meat              226         27.1
# 3  2024-08-27      112          Banana   Fruits              116         43.4
# 4  2024-07-28      622          Banana   Fruits              500         33.9
#
#    Carbohydrates (g)  Fat (g)  Fiber (g)  Sugars (g)  Sodium (mg)  \
# 0               83.7      1.5        1.5        12.7          752
# 1               13.8      3.2        2.6        12.2          680
# 2               79.1     25.8        3.2        44.7          295
# 3               47.1     16.1        6.5        44.1          307
# 4               75.8     47.0        7.8        19.4          358
#
#    Cholesterol (mg)  Meal_Type  Water_Intake (ml)
# ...

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               10000 non-null  object
#  1   User_ID            10000 non-null  int64
#  2   Food_Item          10000 non-null  object
#  3   Category           10000 non-null  object
#  4   Calories (kcal)    10000 non-null  int64
#  5   Protein (g)        10000 non-null  float64
#  6   Carbohydrates (g)  10000 non-null  float64
#  7   Fat (g)            10000 non-null  float64
#  8   Fiber (g)          10000 non-null  float64
#  9   Sugars (g)         10000 non-null  float64
#  10  Sodium (mg)        10000 non-null  int64
#  11  Cholesterol (mg)   10000 non-null  int64
#  12  Meal_Type          10000 non-null  object
#  13  Water_Intake (ml)  10000 non-null  int64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.1+ MB

# %%
print(df_food['Meal_type' == 'Lunch'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(df_food['Meal_type' == 'Lunch'])
#
# ...

# %%
model_id = "distilgpt2"
device = "mps"

# %%
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.pad_token = tokenizer.eos_token

model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
print(df_recipes_NGL.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2231142 entries, 0 to 2231141
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Unnamed: 0   int64
#  1   title        object
#  2   ingredients  object
#  3   directions   object
#  4   link         object
#  5   source       object
#  6   NER          object
# dtypes: int64(1), object(6)
# memory usage: 119.2+ MB
# None

# %%
df_recipes_NGL.head(5)
# Out:
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1  ["1 small jar chipped beef, cut up", "4 boned ...
# 2  ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3  ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4  ["1 c. peanut butter", "3/4 c. graham cracker ...
#
#                                           directions  \
# 0  ["In a heavy 2-quart saucepan, mix brown sugar...
# 1  ["Place chipped beef on bottom of baking dish....
# 2  ["In a slow cooker, combine all ingredients. C...
# 3  ["Boil and debone chicken.", "Put bite size pi...
# 4  ["Combine first four ingredients and press in ...
#
#                                               link    source  \
# ...

# %%
df_recipes_NGL.columns
# Out:
# Index(['Unnamed: 0', 'title', 'ingredients', 'directions', 'link', 'source',
#        'NER'],
#       dtype='object')

# %%
df_recipes_NGL[['title','directions']]
# Out:
#                                                  title  \
# 0                                  No-Bake Nut Cookies
# 1                                Jewell Ball'S Chicken
# 2                                          Creamy Corn
# 3                                        Chicken Funny
# 4                                 Reeses Cups(Candy)
# ...                                                ...
# 2231137                            Sunny's Fake Crepes
# 2231138                                     Devil Eggs
# 2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141                 Polpette in Spicy Tomato Sauce
#
#                                                 directions
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# ...

# %%
# Creating the fuction to add a new columns with two columns
def create_rec_string_col(data):

    dfe = df_recipes_NGL['directions'].to_json()
    dfe
    # necessary to convert the data series into json
    # rec_dir = " ".join(json.loads(data["directions"]))
    rec_dir = " ".join(dfe)
    return rec_dir
    # rec_tit = data['title']
    # rec_string = f"Title: {rec_tit} | Directions:  {rec_dir}"
    # data['rec_string'] = rec_string
    # return data

# %%
df = df_recipes_NGL.apply(create_rec_string_col, axis=1)
df = df.filter(['rec_string'])
df
# Out:
# KeyboardInterrupt

# %%
dfe = df_recipes_NGL['directions'].to_json()
dfe

# %%
from datasets import Dataset

def tokenize_batch(batch):
    return tokenizer(
        batch['rec_string'],
        truncation=True,
        max_length=64,
        return_overflowing_tokens=True
    )
