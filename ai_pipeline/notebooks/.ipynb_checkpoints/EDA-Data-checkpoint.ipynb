# %%
import pandas
import numpy
import matplotlib as mlt
import csv

# %%
with open('C:/Users/user/Downloads/archive (3)/recipes.csv') as f:
# Out:
#   Cell In[3], line 1
#     with open('C:\Users\user\Downloads\archive (3)\recipes.csv') as f:
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
